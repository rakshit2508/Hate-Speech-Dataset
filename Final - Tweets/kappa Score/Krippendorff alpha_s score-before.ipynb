# %%
import krippendorff
import numpy as np

# %%
import pandas as pd

# %%
df = pd.read_excel('tweets_list_modi_jan_5.xlsx')

df
# Out:
#      Unnamed: 0                   Datetime             Tweet Id  \
# 0             0  2022-01-30 18:04:43+00:00  1487849268643729410
# 1             1  2022-01-30 13:09:50+00:00  1487775060337512451
# 2             2  2022-01-29 17:36:43+00:00  1487479834301272064
# 3             3  2022-01-29 08:21:12+00:00  1487340036827885574
# 4             4  2022-01-29 03:41:11+00:00  1487269566736596998
# ..          ...                        ...                  ...
# 770         862  2022-01-30 08:31:13+00:00  1487704943465271296
# 771         863  2022-01-30 19:10:57+00:00  1487865939152367617
# 772         865  2022-01-30 13:43:38+00:00  1487783566238830594
# 773         866  2022-01-30 13:43:04+00:00  1487783424983433220
# 774         867  2022-01-30 13:31:58+00:00  1487780630112849931
#
#                                                   Text         Username  \
# 0    @Anilthapar123 @Blossom_077 @ArvindKejriwal Ka...      ashutos1794
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Datetime', 'Tweet Id', 'Text', 'Username', 'Rakshit',
#        'Ayan ', 'Shreyas', 'Category', 'Category.1', 'Category.2',
#        'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14',
#        'Unnamed: 15'],
#       dtype='object')

# %%
df1 = df[['Rakshit',
       'Ayan ', 'Shreyas']]
df1
# Out:
#      Rakshit  Ayan   Shreyas
# 0          2      2        1
# 1          2      2        1
# 2          2      2        1
# 3          1      1        0
# 4          2      2        1
# ..       ...    ...      ...
# 770        1      0        1
# 771        1      1        1
# 772        2      2        2
# 773        2      1        1
# 774        0      0        0
#
# [775 rows x 3 columns]

# %%
value_count = df1.to_numpy()

# %%
print(value_count)
# Out:
# [[2 2 1]
#  [2 2 1]
#  [2 2 1]
#  ...
#  [2 2 2]
#  [2 1 1]
#  [0 0 0]]

# %%
b=np.transpose(value_count)

# %%
b
# Out:
# array([[2, 2, 2, ..., 2, 2, 0],
#        [2, 2, 2, ..., 2, 1, 0],
#        [1, 1, 1, ..., 2, 1, 0]], dtype=int64)

# %%
print("Krippendorff's alpha for nominal metric: ", krippendorff.alpha(reliability_data=b,
                                                                      level_of_measurement="nominal"))
print("Krippendorff's alpha for interval metric: ", krippendorff.alpha(reliability_data=b))
# Out:
# Krippendorff's alpha for nominal metric:  0.47384601762670986
# Krippendorff's alpha for interval metric:  0.6968456056415663

# %%
print("Krippendorff's alpha for ordinal metric: ", krippendorff.alpha(reliability_data=b,
                                                                      level_of_measurement="ordinal"))
# Out:
# Krippendorff's alpha for ordinal metric:  0.6824587516846512
